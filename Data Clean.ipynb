# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = pd.read_csv('./spa.txt', sep='\t', names= ['eng', 'spa', 'attribution'])

# %%
df.drop(labels=['attribution'], axis=1, inplace = True)

# %%
df.to_csv('./eng-spa.csv', index=None, columns=None)

# %%
import random

# %%
df.iloc[random.randint(0, 125446)]
# Out:
# eng            I am not able to do that because I don't have ...
# spa            No puedo hacerlo porque no tengo suficiente di...
# attribution    CC-BY 2.0 (France) Attribution: tatoeba.org #5...
# Name: 120833, dtype: object

# %%
df.describe()
# Out:
#                           eng      spa
# count                  125446   125446
# unique                 106814   119035
# top     You can put it there.  ¡Órale!
# freq                       32       10

# %%
sns.displot(df['eng'].str.len(), height=10, aspect=2)

# %%
sns.displot(df['eng'].str.len(), height=10, aspect= 2)
